# %% [markdown]
# <a href="https://colab.research.google.com/github/lamarock61/MEV/blob/master/Semana_Booking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
from datetime import datetime, timedelta

# Define the URL
url = "https://api.semana.io/v1/bookings"  # Replace with your target URL

# Define the headers
headers = {
    "X-API-key": "c1a12e98-c596-4806-9246-cd4ec93525c0"
}

# Define the start date as the current date
start_date = datetime.now()

# Calculate the end date as start_date + 6 weeks (42 days)
end_date = start_date + timedelta(days=55)

# Define other JSON data fields
json_data = {
    "period": "day",
    "collaboratorId": 22229
}

# Send POST requests for each date in the range
current_date = start_date
while current_date <= end_date:
    # Set the "type" parameter based on the day of the week
    if current_date.weekday() in (3, 4):  # Thursday or Friday
        json_data["type"] = "remote"
    else:
        json_data["type"] = "office"

    formatted_date = current_date.strftime("%Y-%m-%d")
    json_data["date"] = formatted_date

    response = requests.post(url, headers=headers, json=json_data)

    # Check the response status code
    if response.status_code == 200:
        print(f"Request for date {formatted_date} was successful!")
        print("Response:", response.text)
    else:
        print(f"Request for date {formatted_date} failed with status code:", response.status_code)
        print("Response:", response.text)

    current_date += timedelta(days=1)
# Out:
# Request for date 2023-09-25 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396303,"date":"2023-09-25","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:42:48.603Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-09-26 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396304,"date":"2023-09-26","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:42:50.075Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-09-27 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396306,"date":"2023-09-27","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:42:50.738Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-09-28 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396307,"date":"2023-09-28","type":"remote","collaboratorId":22229,"createdAt":"2023-09-25T12:42:51.131Z","period":"day","floorName":null,"statusId":"3354785e-e9b7-41ae-80cd-03a3d12c6ade","statusLabel":"Télétravail"}}
# Request for date 2023-09-29 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396308,"date":"2023-09-29","type":"remote","collaboratorId":22229,"createdAt":"2023-09-25T12:42:51.551Z","period":"day","floorName":null,"statusId":"3354785e-e9b7-41ae-80cd-03a3d12c6ade","statusLabel":"Télétravail"}}
# Request for date 2023-09-30 failed with status code: 400
# Response: {"ok":false,"error":{"message":"booking-break-policy - not-in-booking-window","code":"unexpected-error"}}
# Request for date 2023-10-01 failed with status code: 400
# Response: {"ok":false,"error":{"message":"booking-break-policy - not-in-booking-window","code":"unexpected-error"}}
# Request for date 2023-10-02 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396309,"date":"2023-10-02","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:42:52.792Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-10-03 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396310,"date":"2023-10-03","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:42:53.538Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-10-04 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396311,"date":"2023-10-04","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:42:54.197Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-10-05 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396312,"date":"2023-10-05","type":"remote","collaboratorId":22229,"createdAt":"2023-09-25T12:42:54.593Z","period":"day","floorName":null,"statusId":"3354785e-e9b7-41ae-80cd-03a3d12c6ade","statusLabel":"Télétravail"}}
# Request for date 2023-10-06 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396314,"date":"2023-10-06","type":"remote","collaboratorId":22229,"createdAt":"2023-09-25T12:42:55.062Z","period":"day","floorName":null,"statusId":"3354785e-e9b7-41ae-80cd-03a3d12c6ade","statusLabel":"Télétravail"}}
# Request for date 2023-10-07 failed with status code: 400
# Response: {"ok":false,"error":{"message":"booking-break-policy - not-in-booking-window","code":"unexpected-error"}}
# Request for date 2023-10-08 failed with status code: 400
# Response: {"ok":false,"error":{"message":"booking-break-policy - not-in-booking-window","code":"unexpected-error"}}
# Request for date 2023-10-09 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396316,"date":"2023-10-09","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:42:56.355Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-10-10 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396317,"date":"2023-10-10","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:42:57.074Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-10-11 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396319,"date":"2023-10-11","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:42:57.817Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-10-12 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396321,"date":"2023-10-12","type":"remote","collaboratorId":22229,"createdAt":"2023-09-25T12:42:58.223Z","period":"day","floorName":null,"statusId":"3354785e-e9b7-41ae-80cd-03a3d12c6ade","statusLabel":"Télétravail"}}
# Request for date 2023-10-13 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396322,"date":"2023-10-13","type":"remote","collaboratorId":22229,"createdAt":"2023-09-25T12:42:58.766Z","period":"day","floorName":null,"statusId":"3354785e-e9b7-41ae-80cd-03a3d12c6ade","statusLabel":"Télétravail"}}
# Request for date 2023-10-14 failed with status code: 400
# Response: {"ok":false,"error":{"message":"booking-break-policy - not-in-booking-window","code":"unexpected-error"}}
# Request for date 2023-10-15 failed with status code: 400
# Response: {"ok":false,"error":{"message":"booking-break-policy - not-in-booking-window","code":"unexpected-error"}}
# Request for date 2023-10-16 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396325,"date":"2023-10-16","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:43:00.031Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-10-17 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396326,"date":"2023-10-17","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:43:00.762Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-10-18 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396327,"date":"2023-10-18","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:43:01.463Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-10-19 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396328,"date":"2023-10-19","type":"remote","collaboratorId":22229,"createdAt":"2023-09-25T12:43:01.885Z","period":"day","floorName":null,"statusId":"3354785e-e9b7-41ae-80cd-03a3d12c6ade","statusLabel":"Télétravail"}}
# Request for date 2023-10-20 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396329,"date":"2023-10-20","type":"remote","collaboratorId":22229,"createdAt":"2023-09-25T12:43:02.264Z","period":"day","floorName":null,"statusId":"3354785e-e9b7-41ae-80cd-03a3d12c6ade","statusLabel":"Télétravail"}}
# Request for date 2023-10-21 failed with status code: 400
# Response: {"ok":false,"error":{"message":"booking-break-policy - not-in-booking-window","code":"unexpected-error"}}
# Request for date 2023-10-22 failed with status code: 400
# Response: {"ok":false,"error":{"message":"booking-break-policy - not-in-booking-window","code":"unexpected-error"}}
# Request for date 2023-10-23 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396332,"date":"2023-10-23","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:43:03.423Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-10-24 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396333,"date":"2023-10-24","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:43:04.068Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-10-25 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396334,"date":"2023-10-25","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:43:04.833Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-10-26 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396335,"date":"2023-10-26","type":"remote","collaboratorId":22229,"createdAt":"2023-09-25T12:43:05.250Z","period":"day","floorName":null,"statusId":"3354785e-e9b7-41ae-80cd-03a3d12c6ade","statusLabel":"Télétravail"}}
# Request for date 2023-10-27 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396337,"date":"2023-10-27","type":"remote","collaboratorId":22229,"createdAt":"2023-09-25T12:43:05.754Z","period":"day","floorName":null,"statusId":"3354785e-e9b7-41ae-80cd-03a3d12c6ade","statusLabel":"Télétravail"}}
# Request for date 2023-10-28 failed with status code: 400
# Response: {"ok":false,"error":{"message":"booking-break-policy - not-in-booking-window","code":"unexpected-error"}}
# Request for date 2023-10-29 failed with status code: 400
# Response: {"ok":false,"error":{"message":"booking-break-policy - not-in-booking-window","code":"unexpected-error"}}
# Request for date 2023-10-30 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396339,"date":"2023-10-30","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:43:07.317Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-10-31 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396341,"date":"2023-10-31","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:43:08.024Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-11-01 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396342,"date":"2023-11-01","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:43:08.763Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-11-02 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396343,"date":"2023-11-02","type":"remote","collaboratorId":22229,"createdAt":"2023-09-25T12:43:09.245Z","period":"day","floorName":null,"statusId":"3354785e-e9b7-41ae-80cd-03a3d12c6ade","statusLabel":"Télétravail"}}
# Request for date 2023-11-03 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396344,"date":"2023-11-03","type":"remote","collaboratorId":22229,"createdAt":"2023-09-25T12:43:09.637Z","period":"day","floorName":null,"statusId":"3354785e-e9b7-41ae-80cd-03a3d12c6ade","statusLabel":"Télétravail"}}
# Request for date 2023-11-04 failed with status code: 400
# Response: {"ok":false,"error":{"message":"booking-break-policy - not-in-booking-window","code":"unexpected-error"}}
# Request for date 2023-11-05 failed with status code: 400
# Response: {"ok":false,"error":{"message":"booking-break-policy - not-in-booking-window","code":"unexpected-error"}}
# Request for date 2023-11-06 failed with status code: 201
# Response: {"ok":true,"data":{"id":9396348,"date":"2023-11-06","type":"office","collaboratorId":22229,"createdAt":"2023-09-25T12:43:10.845Z","period":"day","floorName":"5ème","statusId":"edbcb88e-6a99-490a-a4ce-0a3e01d751b7","statusLabel":"Bureau"}}
# Request for date 2023-11-07 failed with status code: 400
# Response: {"ok":false,"error":{"message":"bad-request - The booking date must be within the next 6 weeks","code":"unexpected-error"}}
# Request for date 2023-11-08 failed with status code: 400
# Response: {"ok":false,"error":{"message":"bad-request - The booking date must be within the next 6 weeks","code":"unexpected-error"}}
# Request for date 2023-11-09 failed with status code: 400
# Response: {"ok":false,"error":{"message":"bad-request - The booking date must be within the next 6 weeks","code":"unexpected-error"}}
# Request for date 2023-11-10 failed with status code: 400
# Response: {"ok":false,"error":{"message":"bad-request - The booking date must be within the next 6 weeks","code":"unexpected-error"}}
# Request for date 2023-11-11 failed with status code: 400
# Response: {"ok":false,"error":{"message":"bad-request - The booking date must be within the next 6 weeks","code":"unexpected-error"}}
# Request for date 2023-11-12 failed with status code: 400
# Response: {"ok":false,"error":{"message":"bad-request - The booking date must be within the next 6 weeks","code":"unexpected-error"}}
# Request for date 2023-11-13 failed with status code: 400
# Response: {"ok":false,"error":{"message":"bad-request - The booking date must be within the next 6 weeks","code":"unexpected-error"}}
# Request for date 2023-11-14 failed with status code: 400
# Response: {"ok":false,"error":{"message":"bad-request - The booking date must be within the next 6 weeks","code":"unexpected-error"}}
# Request for date 2023-11-15 failed with status code: 400
# Response: {"ok":false,"error":{"message":"bad-request - The booking date must be within the next 6 weeks","code":"unexpected-error"}}
# Request for date 2023-11-16 failed with status code: 400
# Response: {"ok":false,"error":{"message":"bad-request - The booking date must be within the next 6 weeks","code":"unexpected-error"}}
# Request for date 2023-11-17 failed with status code: 400
# Response: {"ok":false,"error":{"message":"bad-request - The booking date must be within the next 6 weeks","code":"unexpected-error"}}
# Request for date 2023-11-18 failed with status code: 400
# Response: {"ok":false,"error":{"message":"bad-request - The booking date must be within the next 6 weeks","code":"unexpected-error"}}
# Request for date 2023-11-19 failed with status code: 400
# Response: {"ok":false,"error":{"message":"bad-request - The booking date must be within the next 6 weeks","code":"unexpected-error"}}
